# %%
import mip
import pandas as pd
from models.scripts.m4 import calc_time_m4
from models.utils import calc_cost

# %%
INSTANCES = pd.read_csv("../../input/input_.csv")

# %%
Q1 = {
        'query_id': 1,
        'cpu_h': 2,
        'total_reads': 800,
        'cache_skew': 0.6,
        'first_read_from_s3': False,
        'spooling_fraction': 0.2,
        'spooling_skew': 0.5,
        'scaling_param': 0.1,
        'max_instance_count': 1,
        "max_cores": 3
}

Q1['spooling_read_sum'] = Q1['spooling_fraction'] * Q1['total_reads']

Q2 = {
        'query_id': 2,
        'cpu_h': 30,
        'total_reads': 3,
        'cache_skew': 0.4,
        'first_read_from_s3': False,
        'spooling_fraction': 0.5,
        'spooling_skew': 0.3,
        'scaling_param': 0.2,
        'max_instance_count': 1,
        "max_cores": 3
}

Q2['spooling_read_sum'] = Q2['spooling_fraction'] * Q2['total_reads']


QUERIES = [Q1, Q2]

# %%
q_cols = [
        'query_id',
        "time_cpu",
        "rw_mem",
        "rw_sto",
        "rw_s3",
        "used_mem",
        "used_sto",
        "used_cores"
]

query_req = []

for q in QUERIES:
        times = calc_time_m4(INSTANCES, q)
        times = calc_cost(times)
        display(times[0])
        best =times[0].iloc[0]
        best["used_mem"] = best['used_mem_caching'] + best['used_mem_spooling']
        best["used_sto"] = best['used_sto_caching'] + best['used_sto_spooling']
        best["query_id"] = q["query_id"]
        query_req.append(best[q_cols])
# Out:
#           id_name  count               id  cost_usdph  read_cache_load  \
# 5    c5n.18xlarge      1   c5n.18xlarge/1       3.888              0.0
# 1     c5.24xlarge      1    c5.24xlarge/1       4.080              0.0
# 12   z1d.12xlarge      1   z1d.12xlarge/1       4.464              0.0
# 7    c5d.24xlarge      1   c5d.24xlarge/1       4.608              0.0
# 0     m5.24xlarge      1    m5.24xlarge/1       4.608              0.0
# 13    i3.16xlarge      1    i3.16xlarge/1       4.992              0.0
# 6    m5d.24xlarge      1   m5d.24xlarge/1       5.424              0.0
# 11   m5n.24xlarge      1   m5n.24xlarge/1       5.712              0.0
# 8     r5.24xlarge      1    r5.24xlarge/1       6.048              0.0
# 10  m5dn.24xlarge      1  m5dn.24xlarge/1       6.528              0.0
# 3    r5d.24xlarge      1   r5d.24xlarge/1       6.912              0.0
# 2    r5n.24xlarge      1   r5n.24xlarge/1       7.152              0.0
# 14  r5dn.24xlarge      1  r5dn.24xlarge/1       8.016              0.0
# 4   i3en.24xlarge      1  i3en.24xlarge/1      10.848              0.0
# 9    x1e.32xlarge      1   x1e.32xlarge/1      26.688              0.0
#
#     read_cache_mem  read_cache_sto  read_cache_s3  read_spool_mem  \
# 5           317.20            0.00         482.80          121.87
# 1           317.20            0.00         482.80          121.87
# 12          432.60          367.40           0.00          160.00
# 7           317.20          482.80           0.00          121.87
# 0           432.60            0.00         367.40          160.00
# 13          480.60          319.40           0.00          160.00
# 6           432.60          367.40           0.00          160.00
# 11          432.60            0.00         367.40          160.00
# 8           585.05            0.00         214.95          160.00
# 10          432.60            0.00         367.40          160.00
# 3           585.05          214.95           0.00          160.00
# 2           585.05            0.00         214.95          160.00
# 14          585.05            0.00         214.95          160.00
# 4           585.05          214.95           0.00          160.00
# 9           800.00            0.00           0.00          160.00
#
#     read_spool_sto  ...  time_sto  time_s3  time_xchg  stat_time_sum  \
# 5             0.00  ...      0.00    55.91        0.0        2467.13
# 1             0.00  ...      0.00   223.62        0.0        2634.84
# 12            0.00  ...     91.85     0.00        0.0        2415.05
# 7            38.13  ...     69.88     0.00        0.0        2411.22
# 0             0.00  ...      0.00   146.96        0.0        2562.01
# 13            0.00  ...     19.96     0.00        0.0        2416.01
# 6             0.00  ...     45.92     0.00        0.0        2415.05
# 11            0.00  ...      0.00    36.74        0.0        2451.79
# 8             0.00  ...      0.00    85.98        0.0        2504.08
# 10            0.00  ...      0.00    36.74        0.0        2451.79
# 3             0.00  ...     26.87     0.00        0.0        2418.10
# 2             0.00  ...      0.00    21.49        0.0        2439.59
# 14            0.00  ...      0.00    21.49        0.0        2439.59
# 4             0.00  ...     13.43     0.00        0.0        2418.10
# 9             0.00  ...      0.00     0.00        0.0        2422.40
#
#     stat_time_max  stat_time_period  used_cores  time_load  scale  \
# 5          2400.0               NaN           3        0.0    1.0
# 1          2400.0               NaN           3        0.0    1.0
# 12         2400.0               NaN           3        0.0    1.0
# 7          2400.0               NaN           3        0.0    1.0
# 0          2400.0               NaN           3        0.0    1.0
# 13         2400.0               NaN           3        0.0    1.0
# 6          2400.0               NaN           3        0.0    1.0
# 11         2400.0               NaN           3        0.0    1.0
# 8          2400.0               NaN           3        0.0    1.0
# 10         2400.0               NaN           3        0.0    1.0
# 3          2400.0               NaN           3        0.0    1.0
# 2          2400.0               NaN           3        0.0    1.0
# 14         2400.0               NaN           3        0.0    1.0
# 4          2400.0               NaN           3        0.0    1.0
# 9          2400.0               NaN           3        0.0    1.0
#
#     stat_price_sum
# 5            2.665
# 1            2.986
# 12           2.995
# 7            3.086
# 0            3.279
# 13           3.350
# 6            3.639
# 11           3.890
# 8            4.207
# 10           4.446
# 3            4.643
# 2            4.847
# 14           5.432
# 4            7.287
# 9           17.958
#
# [15 rows x 33 columns]
# /tmp/ipykernel_78348/322994913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_mem"] = best['used_mem_caching'] + best['used_mem_spooling']
# /tmp/ipykernel_78348/322994913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_mem"] = best['used_mem_caching'] + best['used_mem_spooling']
# /tmp/ipykernel_78348/322994913.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_sto"] = best['used_sto_caching'] + best['used_sto_spooling']
# /tmp/ipykernel_78348/322994913.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_sto"] = best['used_sto_caching'] + best['used_sto_spooling']
# /tmp/ipykernel_78348/322994913.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["query_id"] = q["query_id"]
# /tmp/ipykernel_78348/322994913.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["query_id"] = q["query_id"]
#           id_name  count               id  cost_usdph  read_cache_load  \
# 5    c5n.18xlarge      1   c5n.18xlarge/1       3.888              0.0
# 1     c5.24xlarge      1    c5.24xlarge/1       4.080              0.0
# 12   z1d.12xlarge      1   z1d.12xlarge/1       4.464              0.0
# 0     m5.24xlarge      1    m5.24xlarge/1       4.608              0.0
# 7    c5d.24xlarge      1   c5d.24xlarge/1       4.608              0.0
# 13    i3.16xlarge      1    i3.16xlarge/1       4.992              0.0
# 6    m5d.24xlarge      1   m5d.24xlarge/1       5.424              0.0
# 11   m5n.24xlarge      1   m5n.24xlarge/1       5.712              0.0
# 8     r5.24xlarge      1    r5.24xlarge/1       6.048              0.0
# 10  m5dn.24xlarge      1  m5dn.24xlarge/1       6.528              0.0
# 3    r5d.24xlarge      1   r5d.24xlarge/1       6.912              0.0
# 2    r5n.24xlarge      1   r5n.24xlarge/1       7.152              0.0
# 14  r5dn.24xlarge      1  r5dn.24xlarge/1       8.016              0.0
# 4   i3en.24xlarge      1  i3en.24xlarge/1      10.848              0.0
# 9    x1e.32xlarge      1   x1e.32xlarge/1      26.688              0.0
#
#     read_cache_mem  read_cache_sto  read_cache_s3  read_spool_mem  \
# 5              3.0             0.0            0.0             2.0
# 1              3.0             0.0            0.0             2.0
# 12             3.0             0.0            0.0             2.0
# 0              3.0             0.0            0.0             2.0
# 7              3.0             0.0            0.0             2.0
# 13             3.0             0.0            0.0             2.0
# 6              3.0             0.0            0.0             2.0
# 11             3.0             0.0            0.0             2.0
# 8              3.0             0.0            0.0             2.0
# 10             3.0             0.0            0.0             2.0
# 3              3.0             0.0            0.0             2.0
# 2              3.0             0.0            0.0             2.0
# 14             3.0             0.0            0.0             2.0
# 4              3.0             0.0            0.0             2.0
# 9              3.0             0.0            0.0             2.0
#
#     read_spool_sto  ...  time_sto  time_s3  time_xchg  stat_time_sum  \
# 5              0.0  ...       0.0      0.0        0.0       36000.14
# 1              0.0  ...       0.0      0.0        0.0       36000.14
# 12             0.0  ...       0.0      0.0        0.0       36000.14
# 0              0.0  ...       0.0      0.0        0.0       36000.14
# 7              0.0  ...       0.0      0.0        0.0       36000.14
# 13             0.0  ...       0.0      0.0        0.0       36000.14
# 6              0.0  ...       0.0      0.0        0.0       36000.14
# 11             0.0  ...       0.0      0.0        0.0       36000.14
# 8              0.0  ...       0.0      0.0        0.0       36000.14
# 10             0.0  ...       0.0      0.0        0.0       36000.14
# 3              0.0  ...       0.0      0.0        0.0       36000.14
# 2              0.0  ...       0.0      0.0        0.0       36000.14
# 14             0.0  ...       0.0      0.0        0.0       36000.14
# 4              0.0  ...       0.0      0.0        0.0       36000.14
# 9              0.0  ...       0.0      0.0        0.0       36000.14
#
#     stat_time_max  stat_time_period  used_cores  time_load  scale  \
# 5         36000.0               NaN           3        0.0    1.0
# 1         36000.0               NaN           3        0.0    1.0
# 12        36000.0               NaN           3        0.0    1.0
# 0         36000.0               NaN           3        0.0    1.0
# 7         36000.0               NaN           3        0.0    1.0
# 13        36000.0               NaN           3        0.0    1.0
# 6         36000.0               NaN           3        0.0    1.0
# 11        36000.0               NaN           3        0.0    1.0
# 8         36000.0               NaN           3        0.0    1.0
# 10        36000.0               NaN           3        0.0    1.0
# 3         36000.0               NaN           3        0.0    1.0
# 2         36000.0               NaN           3        0.0    1.0
# 14        36000.0               NaN           3        0.0    1.0
# 4         36000.0               NaN           3        0.0    1.0
# 9         36000.0               NaN           3        0.0    1.0
#
#     stat_price_sum
# 5           38.880
# 1           40.800
# 12          44.640
# 0           46.080
# 7           46.080
# 13          49.920
# 6           54.240
# 11          57.120
# 8           60.480
# 10          65.280
# 3           69.120
# 2           71.520
# 14          80.160
# 4          108.480
# 9          266.881
#
# [15 rows x 33 columns]
# /tmp/ipykernel_78348/322994913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_mem"] = best['used_mem_caching'] + best['used_mem_spooling']
# /tmp/ipykernel_78348/322994913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_mem"] = best['used_mem_caching'] + best['used_mem_spooling']
# /tmp/ipykernel_78348/322994913.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_sto"] = best['used_sto_caching'] + best['used_sto_spooling']
# /tmp/ipykernel_78348/322994913.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["used_sto"] = best['used_sto_caching'] + best['used_sto_spooling']
# /tmp/ipykernel_78348/322994913.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["query_id"] = q["query_id"]
# /tmp/ipykernel_78348/322994913.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best["query_id"] = q["query_id"]

# %%
MAX_INSTANCES = 10

# %%
i_cols = [
        'id',
        'mem',
        'sto',
        'cores',
        'mem_bandwidth',
        'sto_bandwidth',
        's3_bandwidth',
        'cost_usdps'
]

instance_info = INSTANCES

instance_info['mem'] = instance_info['calc_mem_caching'] + instance_info['calc_mem_spooling']
instance_info['sto'] = instance_info['calc_sto_caching'] + instance_info['calc_sto_spooling']
instance_info['cost_usdps'] = round(instance_info['cost_usdph'] / 3600, 3)

instance_info = instance_info.rename(columns={
        'calc_cpu_real': 'cores',
        'calc_mem_speed': 'mem_bandwidth',
        'calc_sto_speed': 'sto_bandwidth',
        'calc_s3_speed': 's3_bandwidth'
})[i_cols]

available_instances = instance_info

for i in range(1, MAX_INSTANCES):
        available_instances = pd.concat([available_instances, instance_info], axis=0, ignore_index=True)

available_instances
# Out:
#                 id    mem      sto  cores  mem_bandwidth  sto_bandwidth  \
# 0      m5.24xlarge  384.0      0.0   48.0             50          3.125
# 1      c5.24xlarge  192.0      0.0   48.0             50          3.125
# 2     r5n.24xlarge  768.0      0.0   48.0             50         12.500
# 3     r5d.24xlarge  768.0   3600.0   48.0             50          8.000
# 4    i3en.24xlarge  768.0  60000.0   48.0             50         16.000
# ..             ...    ...      ...    ...            ...            ...
# 145  m5dn.24xlarge  384.0   3600.0   48.0             50          8.000
# 146   m5n.24xlarge  384.0      0.0   48.0             50         12.500
# 147   z1d.12xlarge  384.0   1800.0   24.0             50          4.000
# 148    i3.16xlarge  488.0  15200.0   32.0             50         16.000
# 149  r5dn.24xlarge  768.0   3600.0   48.0             50          8.000
#
#      s3_bandwidth  cost_usdps
# 0             2.5       0.001
# 1             2.5       0.001
# 2            10.0       0.002
# 3             2.5       0.002
# 4            10.0       0.003
# ..            ...         ...
# 145          10.0       0.002
# 146          10.0       0.002
# 147           2.5       0.001
# 148           2.5       0.001
# 149          10.0       0.002
#
# [150 rows x 8 columns]

# %%
MAX_QUERIES_PER_INSTANCE = 1

# %% [markdown]
# ILP Modeling

# %%
query_count = len(query_req)
instance_count = len(available_instances)


# model
model = mip.Model('cost-optimal')

# decision variables
bits = [model.add_var(var_type=mip.BINARY, name=f"bit{i}{q}") for i in range(instance_count) for q in range(query_count)]
instance_runtimes = [model.add_var(var_type=mip.CONTINUOUS, name=f"runtime{i}") for i in range(0, instance_count)]
aux_bits = [model.add_var(var_type=mip.BINARY) for i in range(instance_count) for q1 in range(query_count) for q2 in range(query_count)]
inst_bits = [model.add_var(var_type=mip.BINARY) for i in range(0, instance_count)]

# objective function
model.objective = mip.minimize(mip.xsum(instance_runtimes[i] * available_instances.iloc[i]["cost_usdps"] for i in range(instance_count)))

# constraints
for i in range(instance_count):
        model += mip.xsum(bits[i * query_count + q] for q in range(query_count)) <= MAX_QUERIES_PER_INSTANCE

for i in range(instance_count):
        for q in range(query_count):
                model += inst_bits[i] >= bits[i * query_count + q]

for i in range(instance_count):
        model += inst_bits[i] <= mip.xsum(bits[i * query_count + q] for q in range(query_count))

model += mip.xsum(inst_bits[i] for i in range(instance_count)) <= MAX_INSTANCES


for q in range(query_count):
        for i in range(instance_count):
                print(bits[i * query_count + q].name)
        model += mip.xsum(bits[i * query_count + q] for i in range(instance_count)) == 1

for i in range(instance_count):
        model += mip.xsum(bits[i * query_count + q] * query_req[q]['used_cores'] for q in range(query_count)) <= available_instances.iloc[i]["cores"]

for i in range(instance_count):
        model += mip.xsum(bits[i * query_count + q] * query_req[q]['used_mem'] for q in range(query_count)) <= available_instances.iloc[i]["mem"]

for i in range(instance_count):
        model += mip.xsum(bits[i * query_count + q] * query_req[q]['used_sto'] for q in range(query_count)) <= available_instances.iloc[i]["sto"]

for i in range(instance_count):
        for q in range(query_count):
                model += bits[i * query_count + q] * query_req[q]["time_cpu"] + (
                        query_req[q]["rw_mem"]/available_instances.iloc[i]["mem_bandwidth"] +
                        query_req[q]["rw_sto"]/available_instances.iloc[i]["sto_bandwidth"] +
                        query_req[q]["rw_s3"]/available_instances.iloc[i]["s3_bandwidth"]
                ) * mip.xsum(aux_bits[i * query_count * query_count + q * query_count + p] for p in range(query_count)) <= instance_runtimes[i]

for i in range(instance_count):
        for q in range(query_count):
                for p in range(query_count):
                        model += aux_bits[i * query_count * query_count + q * query_count + p] <= bits[i*query_count + q]
                        model += aux_bits[i * query_count * query_count + q * query_count + p] <= bits[i * query_count + p]
                        model += aux_bits[i * query_count * query_count + q * query_count + p] >=  bits[i * query_count + p] + bits[i*query_count + q] - 1


res = model.optimize()
print("RESULT: ", res)


for i in range(instance_count):
        if instance_runtimes[i].x == 0:
                continue
        print(f"{available_instances.iloc[i]['id']} ({instance_runtimes[i].x})")
        for q in range(query_count):
                if bits[i * query_count + q].x:
                        print(f"Query {query_req[q]['query_id']}")
# Out:
# bit00
# bit10
# bit20
# bit30
# bit40
# bit50
# bit60
# bit70
# bit80
# bit90
# bit100
# bit110
# bit120
# bit130
# bit140
# bit150
# bit160
# bit170
# bit180
# bit190
# bit200
# bit210
# bit220
# bit230
# bit240
# bit250
# bit260
# bit270
# bit280
# bit290
# bit300
# bit310
# bit320
# bit330
# bit340
# bit350
# bit360
# bit370
# bit380
# bit390
# bit400
# bit410
# bit420
# bit430
# bit440
# bit450
# bit460
# bit470
# bit480
# bit490
# bit500
# bit510
# bit520
# bit530
# bit540
# bit550
# bit560
# bit570
# bit580
# bit590
# bit600
# bit610
# bit620
# bit630
# bit640
# bit650
# bit660
# bit670
# bit680
# bit690
# bit700
# bit710
# bit720
# bit730
# bit740
# bit750
# bit760
# bit770
# bit780
# bit790
# bit800
# bit810
# bit820
# bit830
# bit840
# bit850
# bit860
# bit870
# bit880
# bit890
# bit900
# bit910
# bit920
# bit930
# bit940
# bit950
# bit960
# bit970
# bit980
# bit990
# bit1000
# bit1010
# bit1020
# bit1030
# bit1040
# bit1050
# bit1060
# bit1070
# bit1080
# bit1090
# bit1100
# bit1110
# bit1120
# bit1130
# bit1140
# bit1150
# bit1160
# bit1170
# bit1180
# bit1190
# bit1200
# bit1210
# bit1220
# bit1230
# bit1240
# bit1250
# bit1260
# bit1270
# bit1280
# bit1290
# bit1300
# bit1310
# bit1320
# bit1330
# bit1340
# bit1350
# bit1360
# bit1370
# bit1380
# bit1390
# bit1400
# bit1410
# bit1420
# bit1430
# bit1440
# bit1450
# bit1460
# bit1470
# bit1480
# bit1490
# bit01
# bit11
# bit21
# bit31
# bit41
# bit51
# bit61
# bit71
# bit81
# bit91
# bit101
# bit111
# bit121
# bit131
# bit141
# bit151
# bit161
# bit171
# bit181
# bit191
# bit201
# bit211
# bit221
# bit231
# bit241
# bit251
# bit261
# bit271
# bit281
# bit291
# bit301
# bit311
# bit321
# bit331
# bit341
# bit351
# bit361
# bit371
# bit381
# bit391
# bit401
# bit411
# bit421
# bit431
# bit441
# bit451
# bit461
# bit471
# bit481
# bit491
# bit501
# bit511
# bit521
# bit531
# bit541
# bit551
# bit561
# bit571
# bit581
# bit591
# bit601
# bit611
# bit621
# bit631
# bit641
# bit651
# bit661
# bit671
# bit681
# bit691
# bit701
# bit711
# bit721
# bit731
# bit741
# bit751
# bit761
# bit771
# bit781
# bit791
# bit801
# bit811
# bit821
# bit831
# bit841
# bit851
# bit861
# bit871
# bit881
# bit891
# bit901
# bit911
# bit921
# bit931
# bit941
# bit951
# bit961
# bit971
# bit981
# bit991
# bit1001
# bit1011
# bit1021
# bit1031
# bit1041
# bit1051
# bit1061
# bit1071
# bit1081
# bit1091
# bit1101
# bit1111
# bit1121
# bit1131
# bit1141
# bit1151
# bit1161
# bit1171
# bit1181
# bit1191
# bit1201
# bit1211
# bit1221
# bit1231
# bit1241
# bit1251
# bit1261
# bit1271
# bit1281
# bit1291
# bit1301
# bit1311
# bit1321
# bit1331
# bit1341
# bit1351
# bit1361
# bit1371
# bit1381
# bit1391
# bit1401
# bit1411
# bit1421
# bit1431
# bit1441
# bit1451
# bit1461
# bit1471
# bit1481
# bit1491
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Clp0024I Matrix will be packed to eliminate 300 small elements
# Coin0506I Presolve 1833 (-1320) rows, 900 (-300) columns and 4860 (-2640) elements
# Clp0014I Perturbing problem by 0.001% of 11.190692 - largest nonzero change 0.00011010926 ( 0.00397474%) - largest zero change 0.00011005877
# Clp0000I Optimal - objective value 36
# Coin0511I After Postsolve, objective 36, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 36 - 278 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0003I 300 fixed, 0 tightened bounds, 750 strengthened rows, 0 substitutions
# Cgl0004I processed model has 603 rows, 600 columns (450 integer (450 of which binary)) and 1950 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 3.226%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty: 68 orbits (16 useful covering 600 variables), 146 generators, group size: 1.31252e+195 - sparse size 11408 - took 0.037913 seconds
# Cbc0038I Initial state - 7 integers unsatisfied sum - 0.391667
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 38.4 iterations 394
# Cbc0038I Solution found of 38.4
# Cbc0038I Relaxing continuous gives 38.4
# Cbc0038I Before mini branch and bound, 443 integers at bound fixed and 147 continuous
# Cbc0038I Full problem 603 rows 600 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I Round again with cutoff of 38.1599
# Cbc0038I Pass   2: suminf.    0.02501 (4) obj. 38.1599 iterations 236
# Cbc0038I Pass   3: suminf.    0.02501 (4) obj. 38.1599 iterations 105
# Cbc0038I Pass   4: suminf.    0.04179 (7) obj. 38.1599 iterations 25
# Cbc0038I Pass   5: suminf.    0.02501 (4) obj. 38.1599 iterations 26
# Cbc0038I Pass   6: suminf.    0.03918 (7) obj. 38.1599 iterations 37
# Cbc0038I Pass   7: suminf.    0.03918 (7) obj. 38.1599 iterations 62
# Cbc0038I Pass   8: suminf.    0.02501 (4) obj. 38.1599 iterations 55
# Cbc0038I Pass   9: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  10: suminf.    0.42683 (7) obj. 38.1599 iterations 190
# Cbc0038I Pass  11: suminf.    0.02501 (4) obj. 38.1599 iterations 110
# Cbc0038I Pass  12: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  13: suminf.    0.04179 (7) obj. 38.1599 iterations 114
# Cbc0038I Pass  14: suminf.    0.02501 (4) obj. 38.1599 iterations 85
# Cbc0038I Pass  15: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  16: suminf.    0.54682 (8) obj. 38.1599 iterations 115
# Cbc0038I Pass  17: suminf.    0.40516 (8) obj. 38.1599 iterations 119
# Cbc0038I Pass  18: suminf.    0.02501 (4) obj. 38.1599 iterations 255
# Cbc0038I Pass  19: suminf.    0.02501 (4) obj. 38.1599 iterations 10
# Cbc0038I Pass  20: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  21: suminf.    0.54682 (8) obj. 38.1599 iterations 123
# Cbc0038I Pass  22: suminf.    0.40516 (8) obj. 38.1599 iterations 136
# Cbc0038I Pass  23: suminf.    0.02501 (4) obj. 38.1599 iterations 255
# Cbc0038I Pass  24: suminf.    0.03918 (7) obj. 38.1599 iterations 81
# Cbc0038I Pass  25: suminf.    0.02501 (4) obj. 38.1599 iterations 74
# Cbc0038I Pass  26: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  27: suminf.    0.04179 (7) obj. 38.1599 iterations 142
# Cbc0038I Pass  28: suminf.    0.02501 (4) obj. 38.1599 iterations 97
# Cbc0038I Pass  29: suminf.    0.02501 (4) obj. 38.1599 iterations 2
# Cbc0038I Pass  30: suminf.    0.54682 (8) obj. 38.1599 iterations 135
# Cbc0038I Pass  31: suminf.    0.40516 (8) obj. 38.1599 iterations 142
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 387 integers at bound fixed and 129 continuous
# Cbc0038I Full problem 603 rows 600 columns, reduced to 66 rows 84 columns
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 38.4 - took 0.05 seconds
# Cbc0012I Integer solution of 38.4 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0038I Full problem 603 rows 600 columns, reduced to 7 rows 6 columns
# Cbc0031I 6 added rows had average density of 63.833333
# Cbc0013I At root node, 6 cuts changed objective from 36 to 36 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 26 row cuts average 250.8 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency RESULT:  OptimizationStatus.OPTIMAL
# c5d.24xlarge (36000.0)
# Query 2
# i3.16xlarge (2400.0)
# Query 1
